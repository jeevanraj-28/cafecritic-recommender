# %%
import os
os.chdir('..')

# %%
from src.models.hybrid import HybridRecommender
import pandas as pd

df = pd.read_csv('data/processed/cafecritic_processed.csv')
hybrid = HybridRecommender(df)

print("Hybrid Recommendations for User 0:")
print(hybrid.recommend(0, top_n=5, alpha=0.7))
# Out:
# Training SVD...
# SVD trained!
# Computing content similarity...
# Content model ready!
# Hybrid Recommendations for User 0:
#                            cafe  hybrid_score
# 0                   Koffee King        3.2251
# 1              Clean Slate Cafe        3.1799
# 2                 Lloyd's House        3.1724
# 3               GoodFellas Cafe        3.1607
# 4  Movenpick Ice Cream Boutique        3.1511
